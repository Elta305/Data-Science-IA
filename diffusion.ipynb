# %%
import numpy as np
from tqdm.auto import trange, tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train = X_train[y_train.squeeze() == 1]
X_train = (X_train - 127.5) - 1.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 65s 0us/step

# %%
IM_SIZE = 32
BATCH_SIZE = 128
timesteps = 16
time_bar = 1 - np.linspace(0, 1.0, timesteps + 1)

# %%
def cvt_img(img):
    img = img - img.min()
    img = img / img.max()
    return img.astype(np.float32)

def show_examples(x):
    plt.figure(figsize=(10, 10))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.imshow(cvt_img(x[i]))
        plt.axis("off")

show_examples(X_train)

# %%
def forward_noise(x, t):
    a = time_bar[t]
    b = time_bar[t + 1]

    noise = np.random.normal(size=x.shape)
    a = a.reshape((-1, 1, 1, 1))
    b = b.reshape((-1, 1, 1, 1))
    img_a = x * (1 - a) + noise * a
    img_b = x * (1 - b) + noise * b
    return img_a, img_b

def generate_ts(num):
    return np.random.randint(0, timesteps, size=num)

t = generate_ts(25)
a, b = forward_noise(X_train[:25], t)
show_examples(a)

# %%
def block(x_img, x_ts):
    x_parameter = layers.Conv2D(128, kernel_size=3, padding='same')(x_img)
    x_parameter = layers.Activation('relu')(x_parameter)

    time_parameter = layers.Dense(128)(x_ts)
    time_parameter = layers.Activation('relu')(time_parameter)
    time_parameter = layers.Reshape((1, 1, 128))(time_parameter)
    x_parameter = x_parameter * time_parameter


    x_out = layers.Conv2D(128, kernel_size=3, padding='same')(x_img)
    x_out = x_out + x_parameter
    x_out = layers.LayerNormalization()(x_out)
    x_out = layers.Activation('relu')(x_out)
    
    return x_out

# %%
def make_model():
    x = x_input = layers.Input(shape=(IM_SIZE, IM_SIZE, 3), name='x_input')
    
    x_ts = x_ts_input = layers.Input(shape=(1,), name='x_ts_input')
    x_ts = layers.Dense(192)(x_ts)
    x_ts = layers.LayerNormalization()(x_ts)
    x_ts = layers.Activation('relu')(x_ts)
    
    # Down
    x = x32 = block(x, x_ts)
    x = layers.MaxPool2D(2)(x)
    
    x = x16 = block(x, x_ts)
    x = layers.MaxPool2D(2)(x)
    
    x = x8 = block(x, x_ts)
    x = layers.MaxPool2D(2)(x)
    
    x = x4 = block(x, x_ts)
    
    # MLP
    x = layers.Flatten()(x)
    x = layers.Concatenate()([x, x_ts])
    x = layers.Dense(128)(x)
    x = layers.LayerNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Dense(4 * 4 * 32)(x)
    x = layers.LayerNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Reshape((4, 4, 32))(x)
    
    # Up
    x = layers.Concatenate()([x, x4])
    x = block(x, x_ts)
    x = layers.UpSampling2D(2)(x)
    
    x = layers.Concatenate()([x, x8])
    x = block(x, x_ts)
    x = layers.UpSampling2D(2)(x)
    
    x = layers.Concatenate()([x, x16])
    x = block(x, x_ts)
    x = layers.UpSampling2D(2)(x)
    
    x = layers.Concatenate()([x, x32])
    x = block(x, x_ts)
    
    # output
    x = layers.Conv2D(3, kernel_size=1, padding='same')(x)
    model = tf.keras.models.Model([x_input, x_ts_input], x)
    return model

model = make_model()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_ts_input (InputLayer)        [(None, 1)]          0           []
#
#  dense_22 (Dense)               (None, 192)          384         ['x_ts_input[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 192)         384         ['dense_22[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 192)          0           ['layer_normalization_22[0][0]']
#
#  x_input (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  dense_23 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 128)  3584        ['x_input[0][0]']
#
#  activation_56 (Activation)     (None, 128)          0           ['dense_23[0][0]']
#
#  activation_55 (Activation)     (None, 32, 32, 128)  0           ['conv2d_34[0][0]']
#
#  reshape_18 (Reshape)           (None, 1, 1, 128)    0           ['activation_56[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 128)  3584        ['x_input[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 32, 32, 128)  0          ['activation_55[0][0]',
#  a)                                                               'reshape_18[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 32, 32, 128)  0          ['conv2d_35[0][0]',
#  ambda)                                                           'tf.math.multiply_16[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 32, 32, 128)  256        ['tf.__operators__.add_16[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 32, 32, 128)  0           ['layer_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0          ['activation_57[0][0]']
#
#  dense_24 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 128)  147584      ['max_pooling2d_6[0][0]']
#
#  activation_59 (Activation)     (None, 128)          0           ['dense_24[0][0]']
#
#  activation_58 (Activation)     (None, 16, 16, 128)  0           ['conv2d_36[0][0]']
#
#  reshape_19 (Reshape)           (None, 1, 1, 128)    0           ['activation_59[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  147584      ['max_pooling2d_6[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 16, 16, 128)  0          ['activation_58[0][0]',
#  a)                                                               'reshape_19[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 16, 16, 128)  0          ['conv2d_37[0][0]',
#  ambda)                                                           'tf.math.multiply_17[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 16, 16, 128)  256        ['tf.__operators__.add_17[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 16, 16, 128)  0           ['layer_normalization_24[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_60[0][0]']
#
#  dense_25 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 128)    147584      ['max_pooling2d_7[0][0]']
#
#  activation_62 (Activation)     (None, 128)          0           ['dense_25[0][0]']
#
#  activation_61 (Activation)     (None, 8, 8, 128)    0           ['conv2d_38[0][0]']
#
#  reshape_20 (Reshape)           (None, 1, 1, 128)    0           ['activation_62[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 128)    147584      ['max_pooling2d_7[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 8, 8, 128)   0           ['activation_61[0][0]',
#  a)                                                               'reshape_20[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 8, 8, 128)   0           ['conv2d_39[0][0]',
#  ambda)                                                           'tf.math.multiply_18[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 8, 8, 128)   256         ['tf.__operators__.add_18[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 8, 8, 128)    0           ['layer_normalization_25[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_63[0][0]']
#
#  dense_26 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 128)    147584      ['max_pooling2d_8[0][0]']
#
#  activation_65 (Activation)     (None, 128)          0           ['dense_26[0][0]']
#
#  activation_64 (Activation)     (None, 4, 4, 128)    0           ['conv2d_40[0][0]']
#
#  reshape_21 (Reshape)           (None, 1, 1, 128)    0           ['activation_65[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 4, 4, 128)    147584      ['max_pooling2d_8[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, 4, 4, 128)   0           ['activation_64[0][0]',
#  a)                                                               'reshape_21[0][0]']
#
#  tf.__operators__.add_19 (TFOpL  (None, 4, 4, 128)   0           ['conv2d_41[0][0]',
#  ambda)                                                           'tf.math.multiply_19[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 4, 4, 128)   256         ['tf.__operators__.add_19[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 4, 4, 128)    0           ['layer_normalization_26[0][0]']
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['activation_66[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 2240)         0           ['flatten_2[0][0]',
#                                                                   'activation_54[0][0]']
#
#  dense_27 (Dense)               (None, 128)          286848      ['concatenate_10[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 128)         256         ['dense_27[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 128)          0           ['layer_normalization_27[0][0]']
#
#  dense_28 (Dense)               (None, 512)          66048       ['activation_67[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 512)         1024        ['dense_28[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 512)          0           ['layer_normalization_28[0][0]']
#
#  reshape_22 (Reshape)           (None, 4, 4, 32)     0           ['activation_68[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 4, 4, 160)    0           ['reshape_22[0][0]',
#                                                                   'activation_66[0][0]']
#
#  dense_29 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 128)    184448      ['concatenate_11[0][0]']
#
#  activation_70 (Activation)     (None, 128)          0           ['dense_29[0][0]']
#
#  activation_69 (Activation)     (None, 4, 4, 128)    0           ['conv2d_42[0][0]']
#
#  reshape_23 (Reshape)           (None, 1, 1, 128)    0           ['activation_70[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 128)    184448      ['concatenate_11[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, 4, 4, 128)   0           ['activation_69[0][0]',
#  a)                                                               'reshape_23[0][0]']
#
#  tf.__operators__.add_20 (TFOpL  (None, 4, 4, 128)   0           ['conv2d_43[0][0]',
#  ambda)                                                           'tf.math.multiply_20[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 4, 4, 128)   256         ['tf.__operators__.add_20[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 4, 4, 128)    0           ['layer_normalization_29[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 8, 8, 128)   0           ['activation_71[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 8, 8, 256)    0           ['up_sampling2d_6[0][0]',
#                                                                   'activation_63[0][0]']
#
#  dense_30 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 128)    295040      ['concatenate_12[0][0]']
#
#  activation_73 (Activation)     (None, 128)          0           ['dense_30[0][0]']
#
#  activation_72 (Activation)     (None, 8, 8, 128)    0           ['conv2d_44[0][0]']
#
#  reshape_24 (Reshape)           (None, 1, 1, 128)    0           ['activation_73[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 128)    295040      ['concatenate_12[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 8, 8, 128)   0           ['activation_72[0][0]',
#  a)                                                               'reshape_24[0][0]']
#
#  tf.__operators__.add_21 (TFOpL  (None, 8, 8, 128)   0           ['conv2d_45[0][0]',
#  ambda)                                                           'tf.math.multiply_21[0][0]']
#
#  layer_normalization_30 (LayerN  (None, 8, 8, 128)   256         ['tf.__operators__.add_21[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 8, 8, 128)    0           ['layer_normalization_30[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 16, 16, 128)  0          ['activation_74[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 16, 16, 256)  0           ['up_sampling2d_7[0][0]',
#                                                                   'activation_60[0][0]']
#
#  dense_31 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_13[0][0]']
#
#  activation_76 (Activation)     (None, 128)          0           ['dense_31[0][0]']
#
#  activation_75 (Activation)     (None, 16, 16, 128)  0           ['conv2d_46[0][0]']
#
#  reshape_25 (Reshape)           (None, 1, 1, 128)    0           ['activation_76[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_13[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 16, 16, 128)  0          ['activation_75[0][0]',
#  a)                                                               'reshape_25[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 16, 16, 128)  0          ['conv2d_47[0][0]',
#  ambda)                                                           'tf.math.multiply_22[0][0]']
#
#  layer_normalization_31 (LayerN  (None, 16, 16, 128)  256        ['tf.__operators__.add_22[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 16, 16, 128)  0           ['layer_normalization_31[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 32, 32, 128)  0          ['activation_77[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 256)  0           ['up_sampling2d_8[0][0]',
#                                                                   'activation_57[0][0]']
#
#  dense_32 (Dense)               (None, 128)          24704       ['activation_54[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_14[0][0]']
#
#  activation_79 (Activation)     (None, 128)          0           ['dense_32[0][0]']
#
#  activation_78 (Activation)     (None, 32, 32, 128)  0           ['conv2d_48[0][0]']
#
#  reshape_26 (Reshape)           (None, 1, 1, 128)    0           ['activation_79[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_14[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 32, 32, 128)  0          ['activation_78[0][0]',
#  a)                                                               'reshape_26[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 32, 32, 128)  0          ['conv2d_49[0][0]',
#  ambda)                                                           'tf.math.multiply_23[0][0]']
#
#  layer_normalization_32 (LayerN  (None, 32, 32, 128)  256        ['tf.__operators__.add_23[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 32, 32, 128)  0           ['layer_normalization_32[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 3)    387         ['activation_80[0][0]']
#
# ==================================================================================================
# Total params: 3,586,819
# Trainable params: 3,586,819
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0008)
loss_func = tf.keras.losses.MeanAbsoluteError()
model.compile(loss=loss_func, optimizer=optimizer)

# %%
def predict(x_idx=None):
    x = np.random.normal(size=(32, IM_SIZE, IM_SIZE, 3))
    for i in trange(timesteps):
        t = i
        x = model.predict([x, np.full((32), t)], verbose=0)
    show_examples(x)

predict()
# Out:
# 100%|██████████| 16/16 [00:06<00:00,  2.51it/s]

# %%
def predict_step():
    xs = []
    x = np.random.normal(size=(8, IM_SIZE, IM_SIZE, 3))

    for i in trange(timesteps):
        t = i
        x = model.predict([x, np.full((8),  t)], verbose=0)
        if i % 2 == 0:
            xs.append(x[0])

    plt.figure(figsize=(20, 2))
    for i in range(len(xs)):
        plt.subplot(1, len(xs), i+1)
        plt.imshow(cvt_img(xs[i]))
        plt.title(f'{i}')
        plt.axis('off')

predict_step()
# Out:
# 100%|██████████| 16/16 [00:01<00:00,  8.57it/s]

# %%
def train_one(x_img):
    x_ts = generate_ts(len(x_img))
    x_a, x_b = forward_noise(x_img, x_ts)
    loss = model.train_on_batch([x_a, x_ts], x_b)
    return loss

# %%
def train(R=50):
    bar = trange(R)
    total = 100
    for i in bar:
        for j in range(total):
            x_img = X_train[np.random.randint(len(X_train), size=BATCH_SIZE)]
            loss = train_one(x_img)
            pg = (j / total) * 100
            if j % 5 == 0:
                bar.set_description(f'loss: {loss:.5f}, p: {pg:.2f}%')

# %%
for _ in range(10):
    train()
    model.optimizer.learning_rate = max(0.000001, model.optimizer.learning_rate * 0.9)

    predict()
    predict_step()
    plt.show()
# Out:
# loss: 1.56422, p: 95.00%: 100%|██████████| 50/50 [11:22<00:00, 13.64s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.29it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.01it/s]
# loss: 1.26650, p: 95.00%: 100%|██████████| 50/50 [11:06<00:00, 13.33s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.21it/s]
# 100%|██████████| 16/16 [00:00<00:00, 16.89it/s]
# loss: 0.62896, p: 95.00%: 100%|██████████| 50/50 [11:04<00:00, 13.28s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.20it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.21it/s]
# loss: 1.08033, p: 95.00%: 100%|██████████| 50/50 [11:06<00:00, 13.32s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.34it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.00it/s]
# loss: 0.70941, p: 95.00%: 100%|██████████| 50/50 [11:46<00:00, 14.13s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.33it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.33it/s]
# loss: 0.61505, p: 95.00%: 100%|██████████| 50/50 [10:58<00:00, 13.16s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.38it/s]
# 100%|██████████| 16/16 [00:00<00:00, 16.75it/s]
# loss: 0.55165, p: 95.00%: 100%|██████████| 50/50 [10:50<00:00, 13.00s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.75it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.52it/s]
# loss: 0.67840, p: 95.00%: 100%|██████████| 50/50 [10:40<00:00, 12.80s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.55it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.72it/s]
# loss: 0.33422, p: 95.00%: 100%|██████████| 50/50 [10:37<00:00, 12.76s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.86it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.09it/s]
# loss: 0.44229, p: 95.00%: 100%|██████████| 50/50 [10:37<00:00, 12.76s/it]
# 100%|██████████| 16/16 [00:00<00:00, 17.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 17.85it/s]
